# %%
import requests

# %%
url = 'https://hapi.fhir.org/baseR4/patient'

response = requests.get(url)

data = response.json()
body = response.request.body

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 data.requests.body
#
# AttributeError: 'dict' object has no attribute 'requests'

# %%
data_1 = requests.get("https://hapi.fhir.org/baseR4/Patient/90286136").json()
data_1
# Out:
# {'resourceType': 'Patient',
#  'id': '90286136',
#  'meta': {'versionId': '1',
#   'lastUpdated': '2026-02-09T18:38:01.664+00:00',
#   'source': '#RkKiRnP7LI3xO8j6'},
#  'text': {'status': 'generated',
#   'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">NuÃ±ez <b>KARLA </b></div><table class="hapiPropertyTable"><tbody><tr><td>Date of birth</td><td><span>02 January 1980</span></td></tr></tbody></table></div>'},
#  'name': [{'family': 'Karla', 'given': ['NuÃ±ez']}],
#  'gender': 'female',
#  'birthDate': '1980-01-02'}

# %%
data_2 = requests.get("https://hapi.fhir.org/baseR4/Patient/90286136/_history").json()
data_2
# Out:
# {'resourceType': 'Bundle',
#  'id': '32935137-eccd-403b-a2a9-c03da5a6a787',
#  'meta': {'lastUpdated': '2026-05-09T23:38:27.898+00:00'},
#  'type': 'history',
#  'total': 1,
#  'link': [{'relation': 'self',
#    'url': 'https://hapi.fhir.org/baseR4/Patient/90286136/_history'}],
#  'entry': [{'fullUrl': 'https://hapi.fhir.org/baseR4/Patient/90286136',
#    'resource': {'resourceType': 'Patient',
#     'id': '90286136',
#     'meta': {'versionId': '1',
#      'lastUpdated': '2026-02-09T18:38:01.664+00:00',
#      'source': '#RkKiRnP7LI3xO8j6'},
#     'text': {'status': 'generated',
#      'div': '<div xmlns="http://www.w3.org/1999/xhtml"><div class="hapiHeaderText">NuÃ±ez <b>KARLA </b></div><table class="hapiPropertyTable"><tbody><tr><td>Date of birth</td><td><span>02 January 1980</span></td></tr></tbody></table></div>'},
#     'name': [{'family': 'Karla', 'given': ['NuÃ±ez']}],
#     'gender': 'female',
#     'birthDate': '1980-01-02'},
# ...

# %%
data_3 = requests.get ("http://hapi.fhir.org/baseR4/Encounter/89188091")
data_3.json()
# Out:
# {'resourceType': 'Encounter',
#  'id': '89188091',
#  'meta': {'versionId': '1',
#   'lastUpdated': '2026-02-09T17:01:01.338+00:00',
#   'source': '#2G69ns8X4eCdIndY'},
#  'identifier': [{'value': '32294fcd-e050-4487-b3ea-575539241ea3'}],
#  'subject': {'display': 'Bob Bowman'},
#  'period': {'start': '2025-09-01T08:49:54.682000Z'}}

# %%
location = requests.get(" http://hapi.fhir.org/baseR4/Location/131271546")
location.json()
# Out:
# {'resourceType': 'Location',
#  'id': '131271546',
#  'meta': {'versionId': '1',
#   'lastUpdated': '2026-02-13T22:07:59.139+00:00',
#   'source': '#BzPqjkKobjDhh18U'},
#  'status': 'active',
#  'name': 'Main Building'}

# %%
organisation = requests.get("https://hapi.fhir.org/baseR4/Organization/131272945")
organisation.json()
# Out:
# {'resourceType': 'Organization',
#  'id': '131272945',
#  'meta': {'versionId': '1',
#   'lastUpdated': '2026-02-15T06:54:26.639+00:00',
#   'source': '#A3Lz7oZb75LVPpR5',
#   'profile': ['http://hl7.org/fhir/us/core/StructureDefinition/us-core-organization']},
#  'identifier': [{'system': 'http://hl7.org/fhir/sid/us-npi',
#    'value': '9876543210'}],
#  'active': True,
#  'type': [{'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/organization-type',
#      'code': 'prov',
#      'display': 'Healthcare Provider'}]}],
#  'name': 'Boston General Hospital',
#  'telecom': [{'system': 'phone', 'value': '+1-617-555-1000', 'use': 'work'},
#   {'system': 'email',
#    'value': 'info@bostongeneral.example.org',
#    'use': 'work'}],
#  'address': [{'use': 'work',
#    'line': ['789 Hospital Drive'],
#    'city': 'Boston',
#    'state': 'MA',
#    'postalCode': '02115',
#    'country': 'US'}]}

# %%
condition = requests.get("https://hapi.fhir.org/baseR4/Condition/105794714")
condition.json()
# Out:
# {'resourceType': 'Condition',
#  'id': '105794714',
#  'meta': {'versionId': '1',
#   'lastUpdated': '2026-02-10T17:48:47.569+00:00',
#   'source': '#zLRapoEjblct1CoL'},
#  'clinicalStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-clinical',
#     'code': 'active',
#     'display': 'Activo'}]},
#  'verificationStatus': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/condition-ver-status',
#     'code': 'confirmed',
#     'display': 'Confirmado'}]},
#  'category': [{'text': 'Diagnóstico'}],
#  'code': {'coding': [{'system': 'http://snomed.info/sct',
#     'code': '13644009',
#     'display': 'Hipercolesterolemia'}],
#   'text': 'Hipercolesterolemia'},
#  'subject': {'reference': 'Patient/pacientek2bhealt'},
#  'encounter': {'reference': 'Encounter/105794706'},
#  'onsetDateTime': '2019-03-10',
#  'asserter': {'reference': 'Practitioner/dr-perez'}}

# %%
condition = requests.get("https://hapi.fhir.org/baseR4/Condition/105794714")
body = condition.request.body
print(body)
# Out:
# None

# %%
x = 1 
x = x > 5
x
# Out:
# False

# %%
B=[6,1,8,3,5]
B.sort()
B
# Out:
# [1, 3, 5, 6, 8]
