# %%
import pandas
import folium

# %%
import pandas as pd
data = pd.read_csv('hospital_tg.csv', encoding='latin1')
data.sample(5)
# Out:
#     PAYS   VILLE TYPE DE PARTENAIRE  \
# 65  TOGO    LOME           CLINIQUE
# 31  TOGO    KARA            HOPITAL
# 36  TOGO    LOME           CLINIQUE
# 4   TOGO    LOME            CABINET
# 97  TOGO  SOKODE           CLINIQUE
#
#                                     NOM DU PARTENAIRE  \
# 65  CLINIQUE OPHTALMOLOGIQUE LUMIERE DIVINE (C.O.L.D)
# 31                                     CHR KARA TOMDE
# 36                                     CLINIQUE ALPIA
# 4                            CABINET CARDIO 24 (ENAM)
# 97                                POLYCLINIQUE SOKODE
#
#                                            SPECIALITE  \
# 65                                      OPHTALMOLOGIE
# 31  MEDECINE GENERALE, GYNECOLOGIE OBSTETRIQUE, CH...
# 36  MEDECINE GENERALE, GYNECOLOGIE OBSTETRIQUE, AN...
# 4                                         CARDIOLOGIE
# 97  MEDECINE GENERALE, GYNECOLOGIE OBSTETRIQUE, AN...
#
#                          TELEPHONE                                 E-MAIL  \
# ...

# %%
data.dtypes
# Out:
# PAYS                      str
# VILLE                     str
# TYPE DE PARTENAIRE        str
# NOM DU PARTENAIRE         str
# SPECIALITE                str
# TELEPHONE                 str
# E-MAIL                    str
# Latitude              float64
# Longitude             float64
# QUARTIER                  str
# ADRESSE                   str
# dtype: object

# %%
data.drop(['PAYS','E-MAIL','TYPE DE PARTENAIRE', 'TELEPHONE','ADRESSE'], axis=1, inplace=True)
data.sample(5)
# Out:
#        VILLE                            NOM DU PARTENAIRE  \
# 8       LOME                         CABINET DENTAIRE PDG
# 71      LOME                     CLINIQUE SANTE POUR TOUS
# 26  ATAKPAME  CENTRE HOSPITALISER REGIONAL (CHR) ATAKPAME
# 16      LOME                 CABINET MEDICAL SAINT MICHEL
# 66      LOME                   CLINIQUE PERPETUEL SECOURS
#
#                                            SPECIALITE  Latitude  Longitude  \
# 8                                  CHIRURGIE DENTAIRE  6.133687   1.236063
# 71  MEDECINE GENERALE, GYNECOLOGIE OBSTETRIQUE, AN...  6.196813   1.240563
# 26  MEDECINE GENERALE, GYNECOLOGIE OBSTETRIQUE, CH...  7.532563   1.126313
# 16  MEDECINE GENERALE, PEDIATRIE, DERMATOLOGIE, OR...  6.167937   1.202063
# 66  MEDECINE GENERALE, GYNECOLOGIE OBSTETRIQUE, CH...  6.181188   1.197313
#
#                                             QUARTIER
# 8                                          Lome Lome
# 71                                        Lome Kegue
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   VILLE              118 non-null    str
#  1   NOM DU PARTENAIRE  118 non-null    str
#  2   SPECIALITE         118 non-null    str
#  3   Latitude           118 non-null    float64
#  4   Longitude          118 non-null    float64
#  5   QUARTIER           118 non-null    str
# dtypes: float64(2), str(4)
# memory usage: 5.7 KB

# %%
data.describe()
#juste pour verifier s il n y a pas des coordonnees or du togo
# Out:
#          Latitude   Longitude
# count  118.000000  118.000000
# mean     6.749382    1.154378
# std      1.199061    0.199603
# min      6.125687    0.204187
# 25%      6.149906    1.181688
# 50%      6.188562    1.205188
# 75%      6.325750    1.223188
# max     10.871187    1.581438

# %%
data.describe(include='object')
# Out:
# /tmp/ipykernel_52558/3382516499.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   data.describe(include='object')
#        VILLE                               NOM DU PARTENAIRE SPECIALITE  \
# count    118                                             118        118
# unique    27                                             118         58
# top     LOME  CENTRE HOSPITALIER REGIONAL (CHR) LOME COMMUNE    OPTIQUE
# freq      87                                               1         14
#
#          QUARTIER
# count         118
# unique         75
# top     Lome Lome
# ...

# %%
city_counts = data['VILLE'].value_counts()
city_counts
# Out:
# VILLE
# LOME                        87
# KARA                         4
# SOKODE                       3
# KPALIME                      1
# ANEHO                        1
# BASSAR                       1
# BLITTA                       1
# VOGAN                        1
# TSEVIE                       1
# ATAKPAME                     1
# SOTOUBOUA                    1
# DAPAONG                      1
# ADJENGRE - SOTOUBOUA         1
# AHEPE                        1
# ASSAHOUN                     1
# NOTSE                        1
# ADANGBE                      1
# AOUDA - SOTOUBOUA            1
# BAPURE - GUERIN KOUKA        1
# KATCHAMBA - GUERIN KOUKA     1
# KIDJABOUN - GUERIN KOUKA     1
# KPATCHILE - GUERIN KOUKA     1
# NANDOUTA - GUERIN KOUKA      1
# NAWARE - GUERIN KOUKA        1
# TCHEBEBE - SOTOUBOUA         1
# TCHEKPO D                    1
# ZAFI                         1
# Name: count, dtype: int64

# %%
mean_latitude = data['Latitude'].mean()
mean_longitude = data['Longitude'].mean()
m = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=12)
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...
